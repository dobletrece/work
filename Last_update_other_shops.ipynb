# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('results_first_orders_other_shops_since_oct_17.csv', sep = ';', low_memory=False)

# %%
data.head()
# Out:
#    SCM_N_ORDER_NR TDT_T_KEY_ORDER_DATE SCM_OCI_LAND  WEEK_NUMBER  \
# 0        95422910           2017-10-01           C2           39
# 1        95423797           2017-10-01           C2           39
# 2        95423810           2017-10-01           C2           39
# 3        95424773           2017-10-01           C2           39
# 4        95424978           2017-10-01           C2           39
#
#    WEEK_NUMBER_ORDERED  SIT_N_KEY_SITE  OSP_3_LEAD_P_PG_ID  \
# 0                    1              25                15.0
# 1                    1              25               252.0
# 2                    1              25               857.0
# 3                    1              25                33.0
# 4                    1              25               741.0
#
#    OSP_4_LEAD_P_PG_ID  IS_ORDER_ELIGIBLE  SP_SOLD  OSP_NET_VALUE  \
# 0                93.0                  0        0        66.9444
# 1             19467.0                  1        0        50.6244
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307463 entries, 0 to 307462
# Data columns (total 15 columns):
# SCM_N_ORDER_NR             307463 non-null int64
# TDT_T_KEY_ORDER_DATE       307463 non-null object
# SCM_OCI_LAND               307463 non-null object
# WEEK_NUMBER                307463 non-null int64
# WEEK_NUMBER_ORDERED        307463 non-null int64
# SIT_N_KEY_SITE             307463 non-null int64
# OSP_3_LEAD_P_PG_ID         307463 non-null float64
# OSP_4_LEAD_P_PG_ID         307463 non-null float64
# IS_ORDER_ELIGIBLE          307463 non-null int64
# SP_SOLD                    307463 non-null int64
# OSP_NET_VALUE              305842 non-null float64
# CTP_N_KEY_CUSTOMER_TYPE    307463 non-null int64
# SCM_SALES_BMF              307463 non-null float64
# SCM_D_FINANCE_CM1          307463 non-null float64
# SCM_D_FINANCE_CM2          307463 non-null float64
# dtypes: float64(6), int64(7), object(2)
# memory usage: 35.2+ MB

# %%
data.columns
# Out:
# Index(['SCM_N_ORDER_NR', 'TDT_T_KEY_ORDER_DATE', 'SCM_OCI_LAND', 'WEEK_NUMBER',
#        'WEEK_NUMBER_ORDERED', 'SIT_N_KEY_SITE', 'OSP_3_LEAD_P_PG_ID',
#        'OSP_4_LEAD_P_PG_ID', 'IS_ORDER_ELIGIBLE', 'SP_SOLD', 'OSP_NET_VALUE',
#        'CTP_N_KEY_CUSTOMER_TYPE', 'SCM_SALES_BMF', 'SCM_D_FINANCE_CM1',
#        'SCM_D_FINANCE_CM2'],
#       dtype='object')

# %%
list_of_weeks = ['week 1 2017-10'
, 'week 2 2017-10'
, 'week 3 2017-10'
, 'week 4 2017-10'
, 'week 5 2017-10'
, 'week 6 2017-10/11'
, 'week 7 2017-11'
, 'week 8 2017-11'
, 'week 9 2017-11'
, 'week 10 2017-11/12'
, 'week 11 2017-12'
, 'week 12 2017-12'
, 'week 13 2017-12'
, 'week 14 2017-12'
, 'week 15 2018-01'
, 'week 16 2018-01'
, 'week 17 2018-01'
, 'week 18 2018-01'
, 'week 19 2018-01/02'
, 'week 20 2018-02'
, 'week 21 2018-02'
, 'week 22 2018-02'
, 'week 23 2018-02/03'
, 'week 24 2018-03'
, 'week 25 2018-03'
, 'week 26 2018-03'
, 'week 27 2018-03/04'
, 'week 28 2018-04'
, 'week 29 2018-04']

# %%
week_month = {}

# %%
for i in data['WEEK_NUMBER_ORDERED'].value_counts().index.sort_values():
    week_month[i] = list_of_weeks[i-1]

# %%
week_month
# Out:
# {1: 'week 1 2017-10',
#  2: 'week 2 2017-10',
#  3: 'week 3 2017-10',
#  4: 'week 4 2017-10',
#  5: 'week 5 2017-10',
#  6: 'week 6 2017-10/11',
#  7: 'week 7 2017-11',
#  8: 'week 8 2017-11',
#  9: 'week 9 2017-11',
#  10: 'week 10 2017-11/12',
#  11: 'week 11 2017-12',
#  12: 'week 12 2017-12',
#  13: 'week 13 2017-12',
#  14: 'week 14 2017-12',
#  15: 'week 15 2018-01',
#  16: 'week 16 2018-01',
#  17: 'week 17 2018-01',
#  18: 'week 18 2018-01',
#  19: 'week 19 2018-01/02',
#  20: 'week 20 2018-02',
#  21: 'week 21 2018-02',
#  22: 'week 22 2018-02',
#  23: 'week 23 2018-02/03',
#  24: 'week 24 2018-03',
#  25: 'week 25 2018-03',
#  26: 'week 26 2018-03',
#  27: 'week 27 2018-03/04',
#  28: 'week 28 2018-04',
#  29: 'week 29 2018-04'}

# %%
lista0 = [week_month[i] for i in data['WEEK_NUMBER_ORDERED']]

# %%
data['WEEK_MONTH_YEAR'] = lista0

# %%
data['CTP_N_KEY_CUSTOMER_TYPE'].value_counts()
# Out:
# 1    257194
# 2     39581
# 0     10688
# Name: CTP_N_KEY_CUSTOMER_TYPE, dtype: int64

# %%
cust_type = {}

cust_type[0] = 'Registered Existing Customer'
cust_type[1] = 'Registered New Customer'
cust_type[2] = 'Non-Registered New Customer'

# %%
cust_type
# Out:
# {0: 'Registered Existing Customer',
#  1: 'Registered New Customer',
#  2: 'Non-Registered New Customer'}

# %%
lista1 = [cust_type[i] for i in data['CTP_N_KEY_CUSTOMER_TYPE']]

# %%
data['CUS_TYPE'] = lista1

# %%
data['SIT_N_KEY_SITE'].value_counts().index
# Out:
# Int64Index([16, 26, 21, 25, 22, 18, 14, 24, 19, 31, 28, 23, 11, 29, 30, 32,
#             20],
#            dtype='int64')

# %%
shop_id = {}
shop_id[16] = 'CZ'
shop_id[26] = 'SE'
shop_id[21] = 'DK'
shop_id[25] = 'CH'
shop_id[22] = 'HU'
shop_id[18] = 'FI'
shop_id[14] = 'BE'
shop_id[24] = 'RO'
shop_id[19] = 'SK'
shop_id[31] = 'NO'
shop_id[28] = 'PT'
shop_id[23] = 'SI'
shop_id[11] = 'IE'
shop_id[29] = 'HR'
shop_id[30] = 'BG'
shop_id[32] = 'GR'
shop_id[20] = 'RU'

# %%
lista2 = [shop_id[i] for i in data['SIT_N_KEY_SITE']]

# %%
data['SHOP'] = lista2

# %%
import cx_Oracle
conn = cx_Oracle.connect('zooor', 'zoo12or', 'zoorep', threaded=True, encoding = "UTF-8", nencoding = "UTF-8")
curs = conn.cursor()

# %%
data['OSP_3_LEAD_P_PG_ID'].value_counts().index
# Out:
# Float64Index([   251.0,    252.0,     23.0,   2068.0,   2190.0,      9.0,
#                  409.0,     29.0,   2155.0,    741.0,   2192.0,     15.0,
#                  301.0,     33.0,   1540.0,    857.0,     18.0,     20.0,
#                   36.0, 153317.0,    758.0,  49828.0,  40023.0,     42.0,
#                   45.0,     37.0,   1400.0,    221.0,     16.0,     67.0,
#                49821.0,     34.0,    305.0,     62.0,    401.0,     47.0,
#                 2471.0,     38.0,     51.0,     68.0,   1635.0, 207553.0,
#                  274.0,   1106.0,   9788.0, 126729.0,     65.0,    484.0,
#               183134.0, 207624.0,    486.0,   1603.0,  17947.0, 255413.0,
#                   48.0,   9885.0,  68950.0,     50.0,    470.0, 122398.0,
#                 3119.0, 126778.0, 257336.0,  48963.0],
#              dtype='float64')

# %%
query = """select pg_id, pg_shortlink from ZOOMAN.PRODUCT_GROUPS
where pg_id in (251,    252,     23,   2068,   2190,      9,
                 409,     29,   2155,    741,   2192,     15,
                 301,     33,   1540,    857,     18,     20,
                  36, 153317,    758,  49828,  40023,     42,
                  45,     37,   1400,    221,     16,     67,
               49821,     34,    305,     62,    401,     47,
                2471,     38,     51,     68,   1635, 207553,
                 274,   1106,   9788, 126729,     65,    484,
              183134, 207624,    486,   1603,  17947, 255413,
                  48,   9885,  68950,     50,    470, 122398,
                3119, 126778, 257336,  48963)"""

# %%
pg3 = pd.read_sql(query, con = conn)

# %%
pg3
# Out:
#      PG_ID                    PG_SHORTLINK
# 0        9                       hundebett
# 1       15        hundeleine_hundehalsband
# 2       16                       fressnapf
# 3       18                     hundesnacks
# 4       20                  hundespielzeug
# 5       23            kratzbaum_katzenbaum
# 6       29                  katzentoilette
# 7       33                       fressnapf
# 8       34                    katzensnacks
# 9       36                 katzenspielzeug
# 10      37                       transport
# 11      38         katzenfutter_ergaenzung
# 12      42                  kaefigzubehoer
# 13      45                          futter
# 14      47                       spielzeug
# 15      48                          pflege
# 16      50  vogelfutter_nahrungsergaenzung
# 17      51                  kaefigzubehoer
# 18      62                     fischfutter
# 19      65               aquarium_pflanzen
# 20      67                 aquarium_pumpen
# ...

# %%
pg3_dict = {key: value for (key, value) in zip(pg3['PG_ID'], pg3['PG_SHORTLINK'])}

# %%
lista3 = [pg3_dict[i] for i in data['OSP_3_LEAD_P_PG_ID']]

# %%
data['LEAD_PG3_NAME'] = lista3

# %%
data['OSP_4_LEAD_P_PG_ID'].value_counts().index
# Out:
# Float64Index([   682.0,    683.0,  81396.0,   2060.0,   2061.0,   2157.0,
#                17798.0,  31962.0,   2216.0,  97768.0,
#               ...
#                  161.0,    493.0,  35560.0, 174391.0, 257341.0,    796.0,
#               174005.0,   2224.0,     -1.0,   3623.0],
#              dtype='float64', length=668)

# %%
query2 = """select pg_id, pg_shortlink, pg_level from ZOOMAN.PRODUCT_GROUPS
where pg_id in (682,    683,  81396,   2060,   2061,   2157,
               17798,  31962,   2216,  97768,    255,    719,
                2180,    128,  81397,  31963,  18245,   2071,
                  75,   1070,   2230,  35825,   2044,  30936,
               10331, 261925,  74051,    918,     92,   2243,
               10618,    720,  15017,  40193,   1053,   1555,
               49829,    919,    283,  17752,   2304,    465,
               49727,  10623,  17963,    443,  10728,   2613,
               43533,   9425,  39925, 173957,    350,  42545,
                 304,   1544,    323,   2072,    858,   2156,
                 152, 218624,   2051,  55408,     74,    920,
               60757, 155383,    851,   2069,  55409,   2056,
              153321,    528,  23302,    138, 180361,  11751,
                2238,   9498,    110,    394, 151599,   3635,
                2624,    813,    109,  39209, 153271,   9426,
                 118,  49893,  81431,   1413,    854,    146,
                 311, 153275, 171638,  49871, 95904,   3641,   
                 101,   1441,  97657,   2174,
                 286,   3185,  43545,    153,  23080,    259,
                 951,    818,    303,   1412, 153278,    257,
                 757,  35824,  30094,   2232,  43525,    870,
               97982,   1343,   1556,  16637,  55383,   2127,
                2632,   4891,     73,  49833,   3155,    302,
               52404,   1592,  42491, 125246,  40198,  17624,
              201276,  41663,    547, 155106,  35902, 154814,
               72116,   7544, 107296, 251323,  84862, 172210,
              170840,  30289,  38214, 118136, 183148, 104911,
                 276, 239513, 183140,   7914, 235914,   3797,
                9811,   2135, 136620,   1593, 280195, 125586,
                 830,  72732, 256620,  43061, 118181, 170842,
               46084, 122399, 249995, 266991, 2134,    216,   
               2136, 235298,  43482, 118184,
               53385, 214316, 155054, 154529, 152592, 183141,
               24434,    755,  40053, 126615, 118192, 252213,
               82816, 118065, 183143,   8073, 183149,    913,
              183208,   1663,    896, 153131,  72369, 127298,
              179035,   9795,    503, 194757, 139617, 252555,
               53379, 244734, 285668, 140686, 275438, 280194,
               51591, 183145, 251378,  55540,  18154, 122382,
              278911, 251305, 295465, 294133, 227084, 216356,
               52831,  96310, 127248,    497,    161,    493,
               35560, 174391, 257341,    796, 174005,   2224,
              3623)"""

# %%
pg4 = pd.read_sql(query2, con = conn)

# %%
pg4_dict = {key: value for (key, value) in zip(pg4['PG_ID'], pg4['PG_SHORTLINK'])}

# %%
pg4_dict[int('-1')] = 'null'

# %%
pg4_dict
# Out:
# {-1: 'null',
#  52: 'kanarie',
#  53: 'grosssittich',
#  54: 'wellensittich',
#  73: 'hygienebetten',
#  74: 'decken',
#  75: 'hundekissen',
#  92: 'geschirre',
#  93: 'hundeleine_leder',
#  94: 'nylonleinen',
#  95: 'keramik',
#  96: 'kunststoff',
#  97: 'edelstahl',
#  101: 'kauknochen',
#  104: 'kausnacks_natur_vom_rind',
#  108: 'taue_ringe',
#  109: 'autoschutzgitter',
#  110: 'sicherheitsgurte',
#  118: 'buersten',
#  128: 'haubentoiletten',
#  133: 'keramik',
#  134: 'kunststoff',
#  136: 'kratzspielzeug',
#  137: 'spielmaeuse',
#  138: 'transportboxen',
#  139: 'katzengras',
#  140: 'vitamine',
#  146: 'schlafhaeuschen',
#  151: 'hamster',
#  152: 'zwergkaninchen',
#  153: 'meerschweinchen',
#  161: 'verdauung',
#  162: 'badehaeuser',
#  163: 'naepfe_traenken',
#  183: 'flockenfutter',
#  192: 'pflanzenduenger',
#  199: 'innenfilter',
#  215: 'hamster_maeuse',
#  216: 'toiletten',
#  217: 'augen_ohrenpflege',
#  225: 'ratte',
#  226: 'maus_gerbil',
# ...

# %%
lista4 = [pg4_dict[i] for i in data['OSP_4_LEAD_P_PG_ID']]

# %%
data['LEAD_PG4_NAME'] = lista4

# %%
data.columns
# Out:
# Index(['SCM_N_ORDER_NR', 'TDT_T_KEY_ORDER_DATE', 'SCM_OCI_LAND', 'WEEK_NUMBER',
#        'WEEK_NUMBER_ORDERED', 'SIT_N_KEY_SITE', 'OSP_3_LEAD_P_PG_ID',
#        'OSP_4_LEAD_P_PG_ID', 'IS_ORDER_ELIGIBLE', 'SP_SOLD', 'OSP_NET_VALUE',
#        'CTP_N_KEY_CUSTOMER_TYPE', 'SCM_SALES_BMF', 'SCM_D_FINANCE_CM1',
#        'SCM_D_FINANCE_CM2', 'WEEK_MONTH_YEAR', 'CUS_TYPE', 'SHOP',
#        'LEAD_PG3_NAME', 'LEAD_PG4_NAME'],
#       dtype='object')

# %%
data.to_csv('first_orders_other_shops_since_oct_17_updated.csv', sep=';', columns=data.columns, index=False, encoding='utf-8')
